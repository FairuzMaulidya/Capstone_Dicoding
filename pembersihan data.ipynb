# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ('online_retail1.csv')

# %%
df.head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1      1    536365     71053                  WHITE METAL LANTERN       6.0
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2024-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2024-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2024-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2024-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2024-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67111 entries, 0 to 67110
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        67111 non-null  int64
#  1   InvoiceNo    67111 non-null  object
#  2   StockCode    67111 non-null  object
#  3   Description  66942 non-null  object
#  4   Quantity     67110 non-null  float64
#  5   InvoiceDate  67110 non-null  object
#  6   UnitPrice    67110 non-null  float64
#  7   CustomerID   40983 non-null  float64
#  8   Country      67110 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.6+ MB

# %%
df.shape
# Out:
# (67111, 9)

# %%
df.isnull().sum()
# Out:
# index              0
# InvoiceNo          0
# StockCode          0
# Description      169
# Quantity           1
# InvoiceDate        1
# UnitPrice          1
# CustomerID     26128
# Country            1
# dtype: int64

# %%
df = df.drop(columns=['index', 'Country'], errors='ignore')

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 67106    False
# 67107    False
# 67108    False
# 67109    False
# 67110    False
# Length: 67111, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67111 entries, 0 to 67110
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    67111 non-null  object
#  1   StockCode    67111 non-null  object
#  2   Description  66942 non-null  object
#  3   Quantity     67110 non-null  float64
#  4   InvoiceDate  67110 non-null  object
#  5   UnitPrice    67110 non-null  float64
#  6   CustomerID   40983 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 3.6+ MB

# %%
# Simpan Data
df.to_csv('online_retail2.csv', index=False)

# %%
# !git clone https://github.com/FairuzMaulidya/Capstone_Dicoding.git
# Out:
# Cloning into 'Capstone_Dicoding'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 31 (delta 8), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 756.11 KiB | 10.65 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# %cd Capstone_Dicoding
# Out:
# /content/Capstone_Dicoding

# %%
# !git branch
# Out:
# * main

# %%
# !git checkout -b zahwa
# Out:
# Switched to a new branch 'zahwa'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'Another copy of Template Submission Akhir.ipynb'
# '[Clustering] Submission Akhir BMLP_Zahwa Nur Azkia Putri.ipynb'
# 'Copy of BFLD.ipynb'
# 'Copy of [Clustering] Submission Akhir BMLP_Your Name.ipynb'
# 'Copy of [Clustering] Submission Akhir BMLP_Zahwa Nur Azkia Putri.ipynb'
# 'Copy of Latihan BPML 5: Klasifikasi Gambar.ipynb'
# 'Copy of Notebook Pelatihan Analisis Sentimen.ipynb'
# 'Copy of pelatihan_model.ipynb'
# 'Copy of Proyek_Analisis_Sentimen_Fahri.ipynb'
# 'Copy of Revisi_A_1B_Template_Submission_Akhir.ipynb'
# 'Copy of Template Eksperimen MSML'
# 'Copy of Template.ipynb'
# 'Copy of Template Submission Akhir (1).ipynb'
# 'Copy of Template Submission Akhir (2).ipynb'
# 'Copy of Template Submission Akhir (3).ipynb'
# 'Copy of Template Submission Akhir.ipynb'
# 'ILT TECH 4.ipynb'
# '[Klasifikasi] Submission Akhir BMLP_Zahwa Nur Azkia Putri.ipynb'
#  Pelatihan_Model_.ipynb
# 'pembersihan data.ipynb'
#  scrapping.ipynb
# 'submission ml pemula.ipynb'

# %%
# !cp "/content/drive/MyDrive/Capstone/Analisis_RFM.ipynb" /content/Capstone_Dicoding/
